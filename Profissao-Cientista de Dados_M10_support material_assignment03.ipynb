# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
base = pd.read_csv('previsao_de_renda.csv')
base.head()
# Out:
#    Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0           0  2015-01-01   8682    F             False             True
# 1           1  2015-01-01  12830    M              True             True
# 2           2  2015-01-01   2885    M              True             True
# 3           3  2015-01-01  16168    F              True            False
# 4           4  2015-01-01  12438    M             False            False
#
#    qtd_filhos   tipo_renda           educacao estado_civil tipo_residencia  \
# 0           1  Assalariado         Secundário       Casado            Casa
# 1           0   Empresário         Secundário       Casado            Casa
# 2           2  Assalariado  Superior completo       Casado            Casa
# 3           0   Empresário         Secundário       Casado            Casa
# 4           0  Assalariado         Secundário       Casado            Casa
#
#    idade  tempo_emprego  qt_pessoas_residencia    mau    renda
# ...

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
grf_sexo = sns.countplot(x='data_ref',  hue = 'sexo', data=base)

ticks = grf_sexo.set_xticks(list(range(base['data_ref'].nunique())))
labels = grf_sexo.set_xticklabels(base['data_ref'].unique(), rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
grf_veiculo = sns.countplot(x='data_ref',  hue = 'posse_de_veiculo', data=base)

ticks = grf_veiculo.set_xticks(list(range(base['data_ref'].nunique())))
labels = grf_veiculo.set_xticklabels(base['data_ref'].unique(), rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
grf_imovel = sns.countplot(x='data_ref',  hue = 'posse_de_imovel', data=base)

ticks = grf_imovel.set_xticks(list(range(base['data_ref'].nunique())))
labels = grf_imovel.set_xticklabels(base['data_ref'].unique(), rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
grf_tipo_renda = sns.countplot(x='data_ref',  hue = 'tipo_renda', data=base)

ticks = grf_tipo_renda.set_xticks(list(range(base['data_ref'].nunique())))
labels = grf_tipo_renda.set_xticklabels(base['data_ref'].unique(), rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
grf_educ = sns.countplot(x='data_ref',  hue = 'educacao', data=base)

ticks = grf_educ.set_xticks(list(range(base['data_ref'].nunique())))
labels = grf_educ.set_xticklabels(base['data_ref'].unique(), rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
grf_estciv = sns.countplot(x='data_ref',  hue = 'estado_civil', data=base)

ticks = grf_estciv.set_xticks(list(range(base['data_ref'].nunique())))
labels = grf_estciv.set_xticklabels(base['data_ref'].unique(), rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
grf_tipo_res = sns.countplot(x='data_ref',  hue = 'tipo_residencia', data=base)

ticks = grf_tipo_res.set_xticks(list(range(base['data_ref'].nunique())))
labels = grf_tipo_res.set_xticklabels(base['data_ref'].unique(), rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# - Entre Agosto e Setembro de 2015 muitos clientes se formaram.

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %%
base_sexo = base[['data_ref','sexo']].copy()
pvt_sexo = base_sexo.pivot_table(columns='sexo', index='data_ref', aggfunc='value_counts')
gf_pvt_sexo = pvt_sexo.plot()
ticks = gf_pvt_sexo.set_xticks(list(range(base['data_ref'].nunique())))
labels = gf_pvt_sexo.set_xticklabels(base['data_ref'].unique(), rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
gf_pvt_sexo
# Out:
# <AxesSubplot:xlabel='data_ref'>

# %%
base_veiculo = base[['data_ref','posse_de_veiculo']].copy()
pvt_veiculo = base_veiculo.pivot_table(columns='posse_de_veiculo', index='data_ref', aggfunc='value_counts')
gf_pvt_veiculo = pvt_veiculo.plot()
ticks = gf_pvt_veiculo.set_xticks(list(range(base['data_ref'].nunique())))
labels = gf_pvt_veiculo.set_xticklabels(base['data_ref'].unique(), rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
gf_pvt_veiculo
# Out:
# <AxesSubplot:xlabel='data_ref'>

# %%
base_imovel = base[['data_ref','posse_de_imovel']].copy()
pvt_imovel = base_imovel.pivot_table(columns='posse_de_imovel', index='data_ref', aggfunc='value_counts')
gf_pvt_imovel = pvt_imovel.plot()
ticks = gf_pvt_imovel.set_xticks(list(range(base['data_ref'].nunique())))
labels = gf_pvt_imovel.set_xticklabels(base['data_ref'].unique(), rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
gf_pvt_imovel
# Out:
# <AxesSubplot:xlabel='data_ref'>

# %%
base_tipo_renda = base[['data_ref','tipo_renda']].copy()
pvt_tipo_renda = base_tipo_renda.pivot_table(columns='tipo_renda', index='data_ref', aggfunc='value_counts')
gf_pvt_tipo_renda = pvt_tipo_renda.plot()
ticks = gf_pvt_tipo_renda.set_xticks(list(range(base['data_ref'].nunique())))
labels = gf_pvt_tipo_renda.set_xticklabels(base['data_ref'].unique(), rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
gf_pvt_tipo_renda
# Out:
# <AxesSubplot:xlabel='data_ref'>

# %%
base_educ = base[['data_ref','educacao']].copy()
pvt_educ = base_educ.pivot_table(columns='educacao', index='data_ref', aggfunc='value_counts')
gf_pvt_educ = pvt_educ.plot()
ticks = gf_pvt_educ.set_xticks(list(range(base['data_ref'].nunique())))
labels = gf_pvt_educ.set_xticklabels(base['data_ref'].unique(), rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
gf_pvt_educ
# Out:
# <AxesSubplot:xlabel='data_ref'>

# %%
base_est_civ = base[['data_ref','estado_civil']].copy()
pvt_est_civ = base_est_civ.pivot_table(columns='estado_civil', index='data_ref', aggfunc='value_counts')
gf_pvt_est_civ = pvt_est_civ.plot()
ticks = gf_pvt_est_civ.set_xticks(list(range(base['data_ref'].nunique())))
labels = gf_pvt_est_civ.set_xticklabels(base['data_ref'].unique(), rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
gf_pvt_est_civ
# Out:
# <AxesSubplot:xlabel='data_ref'>

# %%
base_tipo_res = base[['data_ref','tipo_residencia']].copy()
pvt_tipo_res = base_tipo_res.pivot_table(columns='tipo_residencia', index='data_ref', aggfunc='value_counts')
gf_pvt_tipo_res = pvt_tipo_res.plot()
ticks = gf_pvt_tipo_res.set_xticks(list(range(base['data_ref'].nunique())))
labels = gf_pvt_tipo_res.set_xticklabels(base['data_ref'].unique(), rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
gf_pvt_tipo_res
# Out:
# <AxesSubplot:xlabel='data_ref'>

# %% [markdown]
# - Fora o grafico da Educação os demais não apresentam mudanças significativas.
